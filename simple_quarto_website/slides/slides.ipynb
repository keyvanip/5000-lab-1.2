# %% [markdown]
# ---
# title: "My Presentation"
# output:
#   quarto::revealjs_presentation:
#     incremental: true
#     theme: black
# ---

# %% [markdown]
# ## Slide 1
# I am a data enthusiast currently pursuing a Master’s degree in Data Science and Analytics at Georgetown University.
#
# ## Slide 2
# My academic journey has equipped me with the skills to tackle complex data challenges, conduct thorough analysis, and communicate insights effectively.
#
# ## Slide 3
# Exploring new places
# ![Image 2](/Users/parsakeyvani/Desktop/lab1.2/5000-lab-1.2/simple_quarto_website/images/travel.png)
#
# ## Slide 4: References
#
# - Parsa, Keyvani. (2020). My Research Paper. Journal of Research, 10(2), 123-145. [1]

# %% [markdown]
# ## Slide 5: Example Image 1
#
# ![Image 1](/Users/parsakeyvani/Desktop/lab1.2/5000-lab-1.2/simple_quarto_website/images/coco.jpg)
#
# ## Slide 6: Example Image 2
#
# ![Image 2](/Users/parsakeyvani/Desktop/lab1.2/5000-lab-1.2/simple_quarto_website/images/djoko.JPG)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(6, 4))
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine Wave')
plt.grid(True)
plt.show()
